# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:\\Users\\vedant jadhav\\OneDrive\\Desktop\\Car Price Prediction\\car_purchasing.csv", encoding="latin-1")

# %%
data.shape
# Out:
# (500, 9)

# %%
data
# Out:
#        customer name                                    customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#           country  gender        age  annual Salary  credit card debt  \
# 0        Bulgaria       0  41.851720    62812.09301      11609.380910
# 1          Belize       0  40.870623    66646.89292       9572.957136
# 2         Algeria       1  43.152897    53798.55112      11160.355060
# 3    Cook Islands       1  58.271369    79370.03798      14426.164850
# 4          Brazil       1  57.313749    59729.15130       5358.712177
# ..            ...     ...        ...            ...               ...
# 495         Nepal       0  41.462515    71942.40291       6995.902524
# 496      Zimbabwe       1  37.642000    56039.49793      12301.456790
# 497   Philippines       1  53.943497    68888.77805      10611.606860
# 498      Botswana       1  59.160509    49811.99062      14013.034510
# 499        marlal       1  46.731152    61370.67766       9391.341628
#
#        net worth  car purchase amount
# 0    238961.2505          35321.45877
# 1    530973.9078          45115.52566
# 2    638467.1773          42925.70921
# 3    548599.0524          67422.36313
# 4    560304.0671          55915.46248
# ..           ...                  ...
# 495  541670.1016          48901.44342
# 496  360419.0988          31491.41457
# 497  764531.3203          64147.28888
# 498  337826.6382          45442.15353
# 499  462946.4924          45107.22566
#
# [500 rows x 9 columns]

# %%
data["Gender2"] = data["gender"].apply(lambda x : "Female" if x==1 else "Male" )

# %%
data["Gender2"].value_counts()
# Out:
# Gender2
# Female    253
# Male      247
# Name: count, dtype: int64

# %%
def age_groups_creation(row):
    if row["age"] < 30:
        return "20-30"
    elif row["age"] <40:
        return "30-40" 
    elif row["age"] <50:
        return "40-50" 
    elif row["age"] <60:
        return "50-60" 
    else:
        return "60-70"

# %%
data["Age Ranges"]= data.apply(age_groups_creation,axis = 1)

# %%
data
# Out:
#        customer name                                    customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#           country  gender        age  annual Salary  credit card debt  \
# 0        Bulgaria       0  41.851720    62812.09301      11609.380910
# 1          Belize       0  40.870623    66646.89292       9572.957136
# 2         Algeria       1  43.152897    53798.55112      11160.355060
# 3    Cook Islands       1  58.271369    79370.03798      14426.164850
# 4          Brazil       1  57.313749    59729.15130       5358.712177
# ..            ...     ...        ...            ...               ...
# 495         Nepal       0  41.462515    71942.40291       6995.902524
# 496      Zimbabwe       1  37.642000    56039.49793      12301.456790
# 497   Philippines       1  53.943497    68888.77805      10611.606860
# 498      Botswana       1  59.160509    49811.99062      14013.034510
# 499        marlal       1  46.731152    61370.67766       9391.341628
#
#        net worth  car purchase amount Gender2 Age Ranges
# 0    238961.2505          35321.45877    Male      40-50
# 1    530973.9078          45115.52566    Male      40-50
# 2    638467.1773          42925.70921  Female      40-50
# 3    548599.0524          67422.36313  Female      50-60
# 4    560304.0671          55915.46248  Female      50-60
# ..           ...                  ...     ...        ...
# 495  541670.1016          48901.44342    Male      40-50
# 496  360419.0988          31491.41457  Female      30-40
# 497  764531.3203          64147.28888  Female      50-60
# 498  337826.6382          45442.15353  Female      50-60
# 499  462946.4924          45107.22566  Female      40-50
#
# [500 rows x 11 columns]

# %%
data.columns
# Out:
# Index(['customer name', 'customer e-mail', 'country', 'gender', 'age',
#        'annual Salary', 'credit card debt', 'net worth', 'car purchase amount',
#        'Gender2', 'Age Ranges'],
#       dtype='object')

# %%
x = data[["age", "annual Salary", "net worth"]]
y = data[["car purchase amount"]]

# %%
y
# Out:
#      car purchase amount
# 0            35321.45877
# 1            45115.52566
# 2            42925.70921
# 3            67422.36313
# 4            55915.46248
# ..                   ...
# 495          48901.44342
# 496          31491.41457
# 497          64147.28888
# 498          45442.15353
# 499          45107.22566
#
# [500 rows x 1 columns]

# %%
x
# Out:
#            age  annual Salary    net worth
# 0    41.851720    62812.09301  238961.2505
# 1    40.870623    66646.89292  530973.9078
# 2    43.152897    53798.55112  638467.1773
# 3    58.271369    79370.03798  548599.0524
# 4    57.313749    59729.15130  560304.0671
# ..         ...            ...          ...
# 495  41.462515    71942.40291  541670.1016
# 496  37.642000    56039.49793  360419.0988
# 497  53.943497    68888.77805  764531.3203
# 498  59.160509    49811.99062  337826.6382
# 499  46.731152    61370.67766  462946.4924
#
# [500 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
len(y_train)
# Out:
# 400

# %%
len(y_test)
# Out:
# 100

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
import joblib
joblib.dump(scaler,"scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
x_test = scaler.fit_transform(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
def modelresults(predictions):
    print("Mean absolute error on model is {}".format(mean_absolute_error(y_test,predictions)))
    print("Root mean squared error on model is {}".format(np.sqrt(mean_squared_error(y_test,predictions))))

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predictions_linear_regression = lr.predict(x_test)

# %%
modelresults(predictions_linear_regression)
# Out:
# Mean absolute error on model is 1560.5238956566482
# Root mean squared error on model is 1847.3421253190663

# %%
data["car purchase amount"].describe()
# Out:
# count      500.000000
# mean     44209.799218
# std      10773.178744
# min       9000.000000
# 25%      37629.896040
# 50%      43997.783390
# 75%      51254.709517
# max      80000.000000
# Name: car purchase amount, dtype: float64

# %%
lr.coef_
# Out:
# array([[6703.9045443 , 6770.5105824 , 5070.74956617]])

# %%
# Model 6719.1940848 * X1 + 6681.22249261 * X2 + 5061.13058738 * X3 = Target

# %%
x.columns
# Out:
# Index(['age', 'annual Salary', 'net worth'], dtype='object')

# %%
# 6719.1940848 * age + 6681.22249261 * annual Salary + 5061.13058738 * net worth = car purchase amount

# %%
from sklearn.svm import SVR

# %%
svrmodel = SVR()

# %%
param_gridsvr = {"C": [0.01,0.1,0.5], "kernel" : ["linear","rbf", "poly"], "degree" : [2,3,4]}

# %%
from sklearn.model_selection import GridSearchCV
gridsvr = GridSearchCV(svrmodel,param_gridsvr)

# %%
gridsvr.fit(x_train,y_train.values.ravel())
# Out:
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [0.01, 0.1, 0.5], 'degree': [2, 3, 4],
#                          'kernel': ['linear', 'rbf', 'poly']})

# %%
predictions_gridsvr = gridsvr.predict(x_test)

# %%
gridsvr.best_params_
# Out:
# {'C': 0.5, 'degree': 2, 'kernel': 'linear'}

# %%
from sklearn.ensemble import RandomForestRegressor
rfrmodel = RandomForestRegressor()
param_gridrfr = {"max_depth": [8,9,10,11,12], "n_estimators": [11,12,10,13,14,15,16,17]}

# %%
gridrfr = GridSearchCV(rfrmodel,param_gridrfr)

# %%
y
# Out:
#      car purchase amount
# 0            35321.45877
# 1            45115.52566
# 2            42925.70921
# 3            67422.36313
# 4            55915.46248
# ..                   ...
# 495          48901.44342
# 496          31491.41457
# 497          64147.28888
# 498          45442.15353
# 499          45107.22566
#
# [500 rows x 1 columns]

# %%
gridrfr.fit(x_train,y_train.values.ravel())
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [8, 9, 10, 11, 12],
#                          'n_estimators': [11, 12, 10, 13, 14, 15, 16, 17]})

# %%
predictionsrfr = gridrfr.predict(x_test)

# %%
modelresults(predictionsrfr)
# Out:
# Mean absolute error on model is 1820.0104057407193
# Root mean squared error on model is 2500.823716364037

# %%
gridrfr.best_params_
# Out:
# {'max_depth': 12, 'n_estimators': 15}

# %%
lr
# Out:
# LinearRegression()

# %%
joblib.dump(lr,"model.pkl")
# Out:
# ['model.pkl']

# %%
model = joblib.load("model.pkl")
model.predict()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[169], line 2
#       1 model = joblib.load("model.pkl")
# ----> 2 model.predict()
#
# TypeError: LinearModel.predict() missing 1 required positional argument: 'X'
